# %%
#pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: requests>=2.31 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-cp310-cp310-win_amd64.whl.metadata (24 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (4.14.2)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from yfinance) (4.25.8)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Downloading yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.2 MB/s  0:00:00
# Downloading frozendict-2.4.7-cp310-cp310-win_amd64.whl (37 kB)
# Downloading peewee-4.0.0-py3-none-any.whl (139 kB)
# Downloading websockets-16.0-cp310-cp310-win_amd64.whl (178 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=c40d8c73556dead4b0f3edb968b778900a15939a363414dca0f6d168e2ec8d59
#   Stored in directory: c:\users\khavy\appdata\local\pip\cache\wheels\e9\25\85\25d2e1cfc0ece64b930b16972f7e4cc3599c43b531f1eba06d
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, websockets, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/6 [peewee]
#    ------------- -------------------------- 2/6 [websockets]
#    ------------- -------------------------- 2/6 [websockets]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    --------------------------------- ------ 5/6 [yfinance]
#    ---------------------------------------- 6/6 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-4.0.0 websockets-16.0 yfinance-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install nsepy
# Out:
# Collecting nsepy
#   Downloading nsepy-0.8.tar.gz (33 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (4.14.2)
# Requirement already satisfied: requests in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (2.32.5)
# Requirement already satisfied: numpy in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (1.24.4)
# Requirement already satisfied: pandas in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (2.2.2)
# Requirement already satisfied: six in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (1.17.0)
# Requirement already satisfied: click in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from nsepy) (8.2.1)
# Collecting lxml (from nsepy)
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from beautifulsoup4->nsepy) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from beautifulsoup4->nsepy) (4.15.0)
# Requirement already satisfied: colorama in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from click->nsepy) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from pandas->nsepy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from pandas->nsepy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from pandas->nsepy) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests->nsepy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests->nsepy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests->nsepy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests->nsepy) (2026.1.4)
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 4.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.4 MB/s  0:00:00
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (pyproject.toml): started
#   Building wheel for nsepy (pyproject.toml): finished with status 'done'
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36107 sha256=895ed3d68fe3ff03b945dae76df2dca27bbfa119edec34f58c883087757c05b0
#   Stored in directory: c:\users\khavy\appdata\local\pip\cache\wheels\4c\87\cb\acaf83f625e5fc73e1fe6e2a8e97680c74cd72391850ef5a86
# Successfully built nsepy
# Installing collected packages: lxml, nsepy
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 2/2 [nsepy]
#
# Successfully installed lxml-6.0.2 nsepy-0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from Descriptive import Descriptive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from Descriptive import Descriptive
#
# ModuleNotFoundError: No module named 'Descriptive'

# %%
from nsepy import get_history as gh
import datetime as dt
start=dt.datetime(2021,6,1)
end=dt.datetime(2022,1,5)
stk_data=gh(symbol='TATACOFFFEE', start=start,end=end)
# Out:
# Exception in thread Thread-14 (get_history):
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\urls.py", line 42, in get_symbol_count
#     return symbol_count[symbol]
# KeyError: 'TATACOFFFEE'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 464, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 1093, in _validate_conn
#     conn.connect()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connection.py", line 796, in connect
# Exception in thread Thread-15 (get_history):
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\urls.py", line 42, in get_symbol_count
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connection.py", line 975, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\ssl_.py", line 483, in ssl_wrap_socket
#     return symbol_count[symbol]
# KeyError: 'TATACOFFFEE'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 464, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 1093, in _validate_conn
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\ssl_.py", line 527, in _ssl_wrap_socket_impl
#     conn.connect()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connection.py", line 796, in connect
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 513, in wrap_socket
#     return self.sslsocket_class._create(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 1104, in _create
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connection.py", line 975, in _ssl_wrap_socket_and_match_hostname
#     self.do_handshake()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 1375, in do_handshake
#     ssl_sock = ssl_wrap_socket(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\ssl_.py", line 483, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\ssl_.py", line 527, in _ssl_wrap_socket_impl
#     self._sslobj.do_handshake()
# ssl.SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 513, in wrap_socket
#     response = self._make_request(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 488, in _make_request
#     return self.sslsocket_class._create(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 1104, in _create
#     raise new_e
# urllib3.exceptions.SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\adapters.py", line 644, in send
#     self.do_handshake()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\ssl.py", line 1375, in do_handshake
#     resp = conn.urlopen(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 841, in urlopen
#     retries = retries.increment(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\retry.py", line 535, in increment
#     self._sslobj.do_handshake()
# ssl.SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /marketinfo/sym_map/symbolCount.jsp?symbol=TATACOFFFEE (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\threading.py", line 1016, in _bootstrap_inner
#     response = self._make_request(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 488, in _make_request
#     raise new_e
# urllib3.exceptions.SSLError: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\adapters.py", line 644, in send
#     self.run()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\commons.py", line 132, in run
#     resp = conn.urlopen(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\connectionpool.py", line 841, in urlopen
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 138, in get_history
#     retries = retries.increment(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\urllib3\util\retry.py", line 535, in increment
#     return get_history_quanta(**kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 142, in get_history_quanta
#     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /marketinfo/sym_map/symbolCount.jsp?symbol=TATACOFFFEE (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\threading.py", line 1016, in _bootstrap_inner
#     url, params, schema, headers, scaling = validate_params(**kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 254, in validate_params
#     params['symbolCount'] = get_symbol_count(symbol)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\urls.py", line 44, in get_symbol_count
#     self.run()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\commons.py", line 132, in run
#     cnt = symbol_count_url(symbol=symbol).text.lstrip().rstrip()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     self.result = self._target(*self._args, **self._kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 138, in get_history
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 602, in get
#     return get_history_quanta(**kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 142, in get_history_quanta
#     return self.request("GET", url, **kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 589, in request
#     url, params, schema, headers, scaling = validate_params(**kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py", line 254, in validate_params
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 724, in send
#     params['symbolCount'] = get_symbol_count(symbol)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\urls.py", line 44, in get_symbol_count
#     history = [resp for resp in gen]
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 724, in <listcomp>
#     cnt = symbol_count_url(symbol=symbol).text.lstrip().rstrip()
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\nsepy\commons.py", line 167, in __call__
#     history = [resp for resp in gen]
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 265, in resolve_redirects
#     return self.session.get(url, params=kwargs, proxies = self.proxy )
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 602, in get
#     resp = self.send(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 703, in send
#     return self.request("GET", url, **kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 589, in request
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\adapters.py", line 675, in send
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 724, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /marketinfo/sym_map/symbolCount.jsp?symbol=TATACOFFFEE (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)')))
#     history = [resp for resp in gen]
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 724, in <listcomp>
#     history = [resp for resp in gen]
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 265, in resolve_redirects
#     resp = self.send(
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\khavy\anaconda3\envs\aiml\lib\site-packages\requests\adapters.py", line 675, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='www1.nseindia.com', port=443): Max retries exceeded with url: /marketinfo/sym_map/symbolCount.jsp?symbol=TATACOFFFEE (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1017)')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       3 start=dt.datetime(2021,6,1)
#       4 end=dt.datetime(2022,1,5)
# ----> 5 stk_data=gh(symbol='TATACOFFFEE', start=start,end=end)
#
# File ~\anaconda3\envs\aiml\lib\site-packages\nsepy\history.py:136, in get_history(symbol, start, end, index, futures, option_type, expiry_date, strike_price, series)
#     134     t1.join()
#     135     t2.join()
# --> 136     return pd.concat((t1.result, t2.result))
#     137 else:
#     138     return get_history_quanta(**kwargs)
#
# AttributeError: 'ThreadReturns' object has no attribute 'result'

# %%
stk_data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 stk_data.info()
#
# NameError: name 'stk_data' is not defined
