# %%
# import sys
# print(sys.executable)
# print(sys.version)
# import tensorflow
# print(tensorflow)
# import tensorflow as tf
# print(tf.__version__)
# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.25.8)
# Requirement already satisfied: setuptools in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.76.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.2.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.1.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.6.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\khavy\anaconda3\envs\aiml\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.2)

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # import the necessary packages
# ----> 2 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       3 from tensorflow.keras.applications import MobileNetV2
#       4 from tensorflow.keras.layers import AveragePooling2D
#
# ModuleNotFoundError: No module named 'tensorflow.keras'
